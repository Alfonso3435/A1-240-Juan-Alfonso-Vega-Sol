# %% [markdown]
# # Matplotlib Exercise AI 240 - 10459
#
# # Instructor - Dr. Uma Gajendragadkar

# %% [markdown]
# ## Use slides from the class and do below exercises
# Use cars dataset if you want for below charts otherwise use data given in slides and draw all below charts in Matplotlib.
#
# Exercise 1 -  Install Matplotlib Library using instruction
#
# !pip install matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ponch\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ponch\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ponch\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# ## Exercise 2 - Import Matplotlib using
#
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 3 - Draw Barchart

# %%
import numpy as np

x = np.array(['A', 'B', 'C', 'D'])
y = np.array([5, 7, 3, 11])

plt.bar(x, y)
plt.show()

# %% [markdown]
# ## Exercise 4 -  Draw Histogram

# %%
data = np.random.randn(1000)

plt.hist(data, bins=20, density = True, color = 'yellow', edgecolor = 'black', alpha = 0.7)
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Customized Histogram with Density')
plt.show()

# %% [markdown]
# ## Exercise 5 -  Draw Piechart

# %%
y = np.array([50, 10, 15, 35])
plt.pie(y)
plt.show()
